# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv("video_game_films.csv")
data
# Out:
#                                             Title Release date  \
# 0                               Super Mario Bros.   1993-05-28
# 1                                   Double Dragon   1994-11-04
# 2                                  Street Fighter   1994-12-23
# 3                                   Mortal Kombat   1995-08-18
# 4                     Mortal Kombat: Annihilation   1997-11-21
# 5                                  Wing Commander   1999-03-12
# 6                         Lara Croft: Tomb Raider   2001-06-15
# 7                                   Resident Evil   2002-03-15
# 8    Lara Croft: Tomb Raider – The Cradle of Life   2003-07-25
# 9                               House of the Dead   2003-10-10
# 10                      Resident Evil: Apocalypse   2004-09-10
# 11                              Alone in the Dark   2005-01-28
# 12                                           Doom   2005-10-21
# 13                                     BloodRayne   2006-01-06
# ...

# %%
data.shape
# Out:
# (42, 7)

# %%
data.size
# Out:
# 294

# %%
data.dropna()
# Out:
#                                             Title Release date  \
# 0                               Super Mario Bros.   1993-05-28
# 2                                  Street Fighter   1994-12-23
# 3                                   Mortal Kombat   1995-08-18
# 4                     Mortal Kombat: Annihilation   1997-11-21
# 5                                  Wing Commander   1999-03-12
# 6                         Lara Croft: Tomb Raider   2001-06-15
# 7                                   Resident Evil   2002-03-15
# 8    Lara Croft: Tomb Raider – The Cradle of Life   2003-07-25
# 9                               House of the Dead   2003-10-10
# 10                      Resident Evil: Apocalypse   2004-09-10
# 11                              Alone in the Dark   2005-01-28
# 12                                           Doom   2005-10-21
# 13                                     BloodRayne   2006-01-06
# 14                                    Silent Hill   2006-04-21
# ...

# %%
plt.figure(figsize=(14,10))
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
a = data["Worldwide box office"].nlargest(10)

# %%
b = data["Worldwide box office"].nsmallest(10)

# %%
plt.figure(figsize=(14,10))
plt.plot(data['Metacritic'])
plt.plot(data['Rotten Tomatoes'])
plt.xlabel('Metacritic')
plt.ylabel('Rotten Tomateos')
# Out:
# Text(0, 0.5, 'Rotten Tomateos')

# %%
plt.figure(figsize=(14,6))
sns.countplot(data['Distributor'])
# Out:
# /Users/md.shamsulhuq/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Distributor', ylabel='count'>

# %%
data.describe()
# Out:
#        Worldwide box office  Rotten Tomatoes  Metacritic
# count          4.200000e+01         40.00000   38.000000
# mean           1.278096e+08         25.77500   35.026316
# std            1.345898e+08         20.03009   13.443549
# min            1.467410e+05          0.00000    9.000000
# 25%            1.284763e+07         10.00000   28.750000
# 50%            8.450896e+07         22.50000   35.000000
# 75%            2.308227e+08         36.25000   44.000000
# max            4.390489e+08         85.00000   66.000000

# %%
plt.hist(data['Worldwide box office'])
# Out:
# (array([16.,  6.,  6.,  2.,  1.,  2.,  3.,  3.,  0.,  3.]),
#  array([1.46741000e+05, 4.40369583e+07, 8.79271756e+07, 1.31817393e+08,
#         1.75707610e+08, 2.19597828e+08, 2.63488045e+08, 3.07378262e+08,
#         3.51268479e+08, 3.95158697e+08, 4.39048914e+08]),
#  <BarContainer object of 10 artists>)

# %%
sns.catplot(data=data, x=data['Distributor'], y=data["Rotten Tomatoes"], kind='swarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 sns.catplot(data=data, x=data['Distributor'], y=data["Rotten Tomatoes"], kind='swarm')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
data['Worldwide box office'].nlargest(10).plot(x=data['Distributor'], kind='bar')
# Out:
# <AxesSubplot:>

# %%
import numpy as np

plt.hist(data["Worldwide box office"])
plt.axvline(np.mean(data['Worldwide box office']), ls='--')
plt.axvline(np.median(data["Worldwide box office"]), ls=':')
plt.xlabel("Mean")
plt.ylabel("Median")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame
